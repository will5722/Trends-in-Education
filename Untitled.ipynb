# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
pd.options.display.float_format="{:,.0f}".format

# %%
Population9 = "resources/population2009.csv"
population09 = pd.read_csv(Population9)

population09.head(5)
#open csv
# Out:
#         State    1-Jul-09    1-Jul-08    1-Jul-07    1-Jul-06    1-Jul-05  \
# 0     Alabama   4,708,708   4,677,464   4,637,904   4,597,688   4,545,049
# 1      Alaska     698,473     688,125     682,297     677,325     669,488
# 2     Arizona   6,595,778   6,499,377   6,362,241   6,192,100   5,974,834
# 3    Arkansas   2,889,450   2,867,764   2,842,194   2,815,097   2,776,221
# 4  California  36,961,664  36,580,371  36,226,122  35,979,208  35,795,255
#
#      1-Jul-04    1-Jul-03    1-Jul-02
# 0   4,512,190   4,490,591   4,472,420
# 1     661,569     650,884     642,691
# 2   5,759,425   5,591,206   5,452,108
# 3   2,746,161   2,722,291   2,704,732
# 4  35,558,419  35,251,107  34,876,194

# %%
Population13 = "resources/poppulation2013.csv"
population013 = pd.read_csv(Population13,encoding="cp1252")

# %%
pop13 = population013[["State","2010","2011","2012","2013"]]

pop13.head(5)
# Out:
#         State        2010        2011        2012        2013
# 0     Alabama   4,785,161   4,801,108   4,816,089   4,830,533
# 1      Alaska     714,021     722,720     731,228     737,442
# 2     Arizona   6,408,208   6,468,732   6,553,262   6,630,799
# 3    Arkansas   2,922,394   2,938,538   2,949,499   2,957,957
# 4  California  37,334,079  37,700,034  38,056,055  38,414,128

# %%
dict = {"1-Jul-09": "2009","1-Jul-08":"2008","1-Jul-07":"2007",
        "1-Jul-06":"2006","1-Jul-05":"2005","1-Jul-04":"2004","1-Jul-03":"2003","1-Jul-02":"2002"}
pop09 = population09.rename(columns = dict)

pop09.head(5)
# Out:
#         State        2009        2008        2007        2006        2005  \
# 0     Alabama   4,708,708   4,677,464   4,637,904   4,597,688   4,545,049
# 1      Alaska     698,473     688,125     682,297     677,325     669,488
# 2     Arizona   6,595,778   6,499,377   6,362,241   6,192,100   5,974,834
# 3    Arkansas   2,889,450   2,867,764   2,842,194   2,815,097   2,776,221
# 4  California  36,961,664  36,580,371  36,226,122  35,979,208  35,795,255
#
#          2004        2003        2002
# 0   4,512,190   4,490,591   4,472,420
# 1     661,569     650,884     642,691
# 2   5,759,425   5,591,206   5,452,108
# 3   2,746,161   2,722,291   2,704,732
# 4  35,558,419  35,251,107  34,876,194

# %%
Population = pd.merge(pop09,pop13, how="inner", on="State")

Population.head(50)
# Out:
#                    State        2009        2008        2007        2006  \
# 0                Alabama   4,708,708   4,677,464   4,637,904   4,597,688
# 1                 Alaska     698,473     688,125     682,297     677,325
# 2                Arizona   6,595,778   6,499,377   6,362,241   6,192,100
# 3               Arkansas   2,889,450   2,867,764   2,842,194   2,815,097
# 4             California  36,961,664  36,580,371  36,226,122  35,979,208
# 5               Colorado   5,024,748   4,935,213   4,842,259   4,753,044
# 6            Connecticut   3,518,288   3,502,932   3,488,633   3,485,162
# 7               Delaware     885,122     876,211     864,896     853,022
# 8   District of Columbia     599,657     590,074     586,409     583,978
# 9                Florida  18,537,969  18,423,878  18,277,888  18,088,505
# 10               Georgia   9,829,211   9,697,838   9,533,761   9,330,086
# 11                Hawaii   1,295,178   1,287,481   1,276,832   1,275,599
# ...

# %%
Population.columns
# Out:
# Index(['State', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
#        '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
Population["State"].tolist
# Out:
# <bound method IndexOpsMixin.tolist of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# ...

# %%
cols = [2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
       '2010', '2011', '2012', '2013']
labels = Population["State"]
# Out:
#   File "<ipython-input-9-f9df027fd8e1>", line 1
#     cols = [2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
#                 ^
# SyntaxError: invalid syntax

# %%
highest_pop_state = Pop["Population"].max()

highest_pop_state

# %%
labels = ["2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013"]

y = pie1_NC_grad100 = by_year["pecentage of grad_100"]

colors = ["Aquamarine","Pink", "Salmon","Coral", "Turquoise","Red", "Cyan",
          "Gold","Blue","Brown","Green","yellow"]

explode = (0,0,0,0,0,0,0,0.07,0,0,0,0.05)

plt.pie(y, explode=explode, colors = colors, labels=labels,
autopct='%1.2f%%', shadow=True, startangle=180)

plt.title(label="Grade_100 Percentage per year",loc="center",fontstyle='italic')

plt.tight_layout()

plt.show()

# %%
lowest_pop_state = Pop["Population"].min()

lowest_pop_state

# %%
"Amber", "Beige", "Citrine","Olive", "Goldenrod", "Saffron","Chartreuse", "Ecru","Sunglow","Aureolin","Emerald","Lime"
"Malachite"

"Sage"  "Pistachio"
Turquoise

Honeydew
